# %% [markdown]
# ### Name: Nipun Singh
# ### Roll no: RK20CHB38
# ### Section: K20CH

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("combined.csv")
data
# Out:
#         userId     displayName          userUrl    joinDate joinTime  \
# 0       708283     bestfitting     /bestfitting  07-09-2016  39:04.8
# 1      1424766          Dieter  /christofhenkel  17-11-2017  39:22.3
# 2       478989     Guanshuo Xu       /wowfattie  02-12-2015  40:13.5
# 3        37166             Psi   /philippsinger  29-03-2012  12:46.3
# 4       448347       Qishen Ha        /haqishen  22-10-2015  50:34.2
# ...        ...             ...              ...         ...      ...
# 16605   220074  Levin Kuhlmann          /levink  31-07-2014  41:42.0
# 16606   317687       WhizWilde      /wildwizard  24-03-2015  04:53.3
# 16607   886737           geher         /gw00207  27-01-2017  53:19.6
# 16608    10035     Net Prophet        /srt19170  20-04-2011  05:54.9
# 16609   100371            Adam         /adamwoz  09-05-2013  08:37.7
#
#       comp_tier dataset_tier notebook_tier discuss_tier final_tier  ...  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16610 entries, 0 to 16609
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   userId                   16610 non-null  int64
#  1   displayName              16610 non-null  object
#  2   userUrl                  16610 non-null  object
#  3   joinDate                 16610 non-null  object
#  4   joinTime                 16610 non-null  object
#  5   comp_tier                16610 non-null  object
#  6   dataset_tier             16610 non-null  object
#  7   notebook_tier            16610 non-null  object
#  8   discuss_tier             16610 non-null  object
#  9   final_tier               16610 non-null  object
#  10  comp_currentRanking      16610 non-null  object
#  11  dataset_currentRanking   16610 non-null  object
#  12  notebook_currentRanking  16610 non-null  object
#  13  discuss_currentRanking   16610 non-null  object
# ...

# %%
data[data['dataset_tier']=='Unranked'].value_counts().sum()
# Out:
# 14574

# %%
data[data['dataset_currentRanking']=='Unranked'].value_counts().sum()
# Out:
# 12822

# %%
data[data['notebook_BronzeMedals']=='Unranked'].value_counts().sum()
# Out:
# 12803

# %%
data[data['discuss_tier']=='Unranked'].value_counts().sum()
# Out:
# 14007

# %%
data.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\NIPUNS~1\AppData\Local\Temp/ipykernel_14916/169168403.py in <module>
# ----> 1 data.info()
#
# NameError: name 'data' is not defined
